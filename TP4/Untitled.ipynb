# %%
import pandas as pd
from itertools import combinations

def load_dataset(file_path):
    """Loads the dataset and performs basic cleaning."""
    data = pd.read_csv(file_path, delimiter=';', decimal='.', na_values=['NaN', 'NA', '', ' '])
    data.dropna(inplace=True)
    print("Dataset loaded successfully.")
    print(f"Dataset shape: {data.shape}")
    print("Sample data:\n", data.head())
    return data

def preprocess_data(data):
    """Keeps relevant columns and prepares the dataset for transactional analysis."""
    data['Set'] = data['Set'].astype(str) 
    data = data.iloc[:, 7:] 
    print(f"Shape after preprocessing: {data.shape}")
    print(f"Remaining columns: {data.columns.tolist()}")
    print("Sample preprocessed data:\n", data.head())
    return data

def count_transactions_items(data):
    """Counts the number of transactions and items in the preprocessed data."""
    num_transactions = data.shape[0]
    num_items = data.shape[1]
    print(f"Number of Transactions: {num_transactions}")
    print(f"Number of Items: {num_items}")
    return num_transactions, num_items

def create_transactional_format(data):
    """Creates a list of transactions, each represented by a tuple of items."""
    transactions = [
        (row['Label'], row['Category'], row['Set']) 
        for _, row in data.iterrows() 
        if pd.notna(row['Label']) and pd.notna(row['Category']) and pd.notna(row['Set'])
    ]
    print(f"Sample Transactions: {transactions[:5]}")
    return transactions

def generate_k_itemsets(transactions, k):
    """Generates candidate k-itemsets from the transactions."""
    itemsets = {tuple(sorted(itemset)) for transaction in transactions for itemset in combinations(transaction, k)}
    print(f"Candidate {k}-itemsets: {itemsets}")
    return itemsets

def calculate_support(transactions, itemsets):
    """Calculates the support of each candidate itemset."""
    total_transactions = len(transactions)
    support_counts = {
        itemset: sum(1 for transaction in transactions if set(itemset).issubset(transaction)) / total_transactions
        for itemset in itemsets
    }
    return support_counts

def generate_frequent_itemsets(transactions, k, min_support):
    """Generates frequent k-itemsets that meet the minimum support threshold."""
    candidates = generate_k_itemsets(transactions, k)
    support_counts = calculate_support(transactions, candidates)
    frequent_itemsets = {itemset: support for itemset, support in support_counts.items() if support >= min_support}
    print(f"Frequent {k}-itemsets: {frequent_itemsets}")
    return frequent_itemsets

def generate_association_rules(frequent_itemsets):
    """Generates association rules from frequent itemsets."""
    rules = []
    for itemset in frequent_itemsets:
        for i in range(1, len(itemset)):
            for antecedent in combinations(itemset, i):
                consequent = set(itemset) - set(antecedent)
                rules.append((antecedent, tuple(consequent)))
    print(f"Generated rules: {rules}")
    return rules

def calculate_confidence(rules, support_counts):
    """Calculates confidence for each association rule."""
    confidence = {}
    for antecedent, consequent in rules:
        support_antecedent = support_counts.get(antecedent, 0)
        support_both = support_counts.get(tuple(sorted(set(antecedent) | set(consequent))), 0)
        if support_antecedent > 0:
            confidence[(antecedent, consequent)] = support_both / support_antecedent
    return confidence

def main():
    file_path = r'D:\M2\DataMining\TP4\DatasetExos.csv'  # Update with your dataset path
    data = load_dataset(file_path)
    data = preprocess_data(data)

    # Count transactions and items
    num_transactions, num_items = count_transactions_items(data)
    transactions = create_transactional_format(data)
    print(f"Total Transactions Created: {len(transactions)}")

    # Set parameters
    min_support = 0.1  
    k = 1

    # Frequent Itemset Extraction
    frequent_itemsets = {}
    while True:
        frequent_k_itemsets = generate_frequent_itemsets(transactions, k, min_support)
        if not frequent_k_itemsets:
            break
        frequent_itemsets[k] = frequent_k_itemsets
        k += 1

    # Generate association rules
    all_rules = []
    support_counts = {tuple(itemset): support for k_itemsets in frequent_itemsets.values() for itemset, support in k_itemsets.items()}
    for k_itemsets in frequent_itemsets.values():
        rules = generate_association_rules(k_itemsets)
        all_rules.extend(rules)

    confidence_results = calculate_confidence(all_rules, support_counts)

    # Output results
    print("Frequent Itemsets:")
    for k, itemsets in frequent_itemsets.items():
        print(f"Frequent {k}-itemsets: {itemsets}")

    print("\nAssociation Rules:")
    for rule, conf in confidence_results.items():
        antecedent, consequent = rule
        print(f"Rule: {antecedent} => {consequent}, Confidence: {conf:.2f}")

if __name__ == "__main__":
    main()
# Out:
# Dataset loaded successfully.
# Dataset shape: (8977, 11)
# Sample data:
#                     ep (ms)                   Acc_x               Acc_y  \
# 0  2019-01-11 15:08:05.200                  0.0135               0.977
# 1  2019-01-11 15:08:05.400  -0.0014999999999999996  0.9704999999999999
# 2  2019-01-11 15:08:05.600   0.0013333333333333333  0.9716666666666667
# 3  2019-01-11 15:08:05.800                  -0.024               0.957
# 4  2019-01-11 15:08:06.000   -0.027999999999999997  0.9576666666666666
#
#                   Acc_z          Gyro_x               Gyro_y  \
# 0                -0.071  -2.094.366.723          257.720.316
# 1  -0.07949999999999999         -16.826              -0.8904
# 2  -0.06433333333333334     526.942.212  -0.2559999999999999
# 3               -0.0735           8.061              -45.244
# 4                -0.115           2.439              -15.486
#
#                Gyro_z ID  Label Category   Set
# 0  0.9388000000000002  B  bench    heavy  30.0
# 1              21.708  B  bench    heavy  30.0
# 2             -14.146  B  bench    heavy  30.0
# 3              -2.073  B  bench    heavy  30.0
# 4             -36.098  B  bench    heavy  30.0
# Shape after preprocessing: (8977, 4)
# Remaining columns: ['ID', 'Label', 'Category', 'Set']
# Sample preprocessed data:
#    ID  Label Category   Set
# 0  B  bench    heavy  30.0
# 1  B  bench    heavy  30.0
# 2  B  bench    heavy  30.0
# 3  B  bench    heavy  30.0
# 4  B  bench    heavy  30.0
# Number of Transactions: 8977
# Number of Items: 4
# Sample Transactions: [('bench', 'heavy', '30.0'), ('bench', 'heavy', '30.0'), ('bench', 'heavy', '30.0'), ('bench', 'heavy', '30.0'), ('bench', 'heavy', '30.0')]
# Total Transactions Created: 8977
# Candidate 1-itemsets: {('83.0',), ('93.0',), ('65.0',), ('56.0',), ('23.0',), ('53.0',), ('54.0',), ('25.0',), ('39.0',), ('18.0',), ('57.0',), ('row',), ('29.0',), ('91.0',), ('heavy',), ('74.0',), ('10.0',), ('50.0',), ('-10.0',), ('31.0',), ('90.0',), ('37.0',), ('22.0',), ('42.0',), ('bench',), ('rest',), ('26.0',), ('82.0',), ('27.0',), ('76.0',), ('34.0',), ('1.0',), ('80.0',), ('73.0',), ('79.0',), ('13.0',), ('16.0',), ('30.0',), ('24.0',), ('44.0',), ('6.0',), ('68.0',), ('55.0',), ('77.0',), ('58.0',), ('7.0',), ('45.0',), ('88.0',), ('78.0',), ('32.0',), ('61.0',), ('72.0',), ('19.0',), ('standing',), ('87.0',), ('52.0',), ('92.0',), ('67.0',
'ohp'), ('6.0', 'dead', 'medium'), ('26.0', 'medium', 'squat'), ('33.0', 'bench', 'heavy'), ('47.0', 'heavy', 'ohp'), ('31.0', 'bench', 'medium'), ('15.0', 'heavy', 'squat'), ('43.0', 'heavy', 'row'), ('41.0', 'medium', 'squat'), ('85.0', 'bench', 'medium'), ('84.0', 'medium', 'ohp'), ('91.0', 'heavy', 'row'), ('7.0', 'bench', 'heavy'), ('65.0', 'heavy', 'row'), ('21.0', 'heavy', 'ohp'), ('36.0', 'medium', 'row'), ('89.0', 'rest', 'sitting'), ('29.0', 'bench', 'medium'), ('57.0', 'medium', 'row'), ('81.0', 'medium', 'ohp'), ('10.0', 'heavy', 'ohp'), ('2000.0', 'medium', 'row'), ('18.0', 'heavy', 'squat'), ('1.0', 'dead', 'medium'), ('75.0', 'dead', 'medium'), ('34.0', 'bench', 'medium'), ('37.0', 'medium', 'ohp'), ('1.0', 'heavy', 'ohp'), ('86.0', 'bench', 'heavy'), ('56.0', 'medium', 'ohp'), ('9.0', 'medium', 'squat'), ('16.0', 'medium', 'squat'), ('55.0', 'dead', 'medium'), ('25.0', 'heavy', 'ohp'), ('83.0', 'bench', 'heavy'), ('42.0', 'heavy', 'row'), ('23.0', 'rest', 'standing'), ('40.0', 'medium', 'row'), ('28.0', 'heavy', 'ohp'), ('35.0', 'heavy', 'row'), ('88.0', 'bench', 'heavy'), ('68.0', 'dead', 'medium'), ('82.0', 'rest', 'sitting'), ('45.0', 'heavy', 'squat'), ('2.0', 'medium', 'squat'), ('20.0', 'heavy', 'row'), ('78.0', 'dead', 'medium'), ('8.0', 'heavy', 'row'), ('60.0', 'rest', 'sitting'), ('90.0', 'heavy', 'row'), ('54.0', 'heavy', 'row'), ('-10.0', 'medium', 'row'), ('92.0', 'bench', 'heavy'), ('30.0', 'bench', 'heavy'), ('51.0', 'rest', 'standing'), ('39.0', 'heavy', 'ohp'), ('4.0', 'medium', 'row'), ('17.0', 'heavy', 'squat'), ('53.0', 'medium', 'row'), ('44.0', 'bench', 'medium'), ('48.0', 'dead', 'heavy'), ('13.0', 'dead', 'heavy'), ('57.0', 'medium', 'raw'), ('62.0', 'bench', 'heavy'), ('74.0', 'bench', 'heavy'), ('69.0', 'dead', 'medium'), ('64.0', 'heavy', 'squat'), ('71.0', 'heavy', 'ohp'), ('38.0', 'heavy', 'ohp'), ('19.0', 'rest', 'standing'), ('24.0', 'heavy', 'ohp'), ('12.0', 'heavy', 'squat'), ('63.0', 'medium', 'row'), ('87.0', 'heavy', 'ohp'), ('66.0', 'heavy', 'row'), ('32.0', 'medium', 'row'), ('79.0', 'heavy', 'squat')}
# Frequent 3-itemsets: {('22.0', 'heavy', 'squat'): 0.010916787345438342, ('70.0', 'medium', 'squat'): 0.014481452601091679, ('73.0', 'heavy', 'squat'): 0.011473766291634177, ('50.0', 'bench', 'medium'): 0.01303330734098251, ('11.0', 'dead', 'medium'): 0.015038431547287512, ('14.0', 'medium', 'row'): 0.011807953659351677, ('27.0', 'dead', 'medium'): 0.015038431547287512, ('49.0', 'medium', 'row'): 0.010916787345438342, ('3.0', 'medium', 'row'): 0.011585162080873342, ('52.0', 'heavy', 'ohp'): 0.010471204188481676, ('77.0', 'medium', 'ohp'): 0.010805391556199176, ('6.0', 'dead', 'medium'): 0.016709368385875015, ('26.0', 'medium', 'squat'): 0.013924473654895846, ('47.0', 'heavy', 'ohp'): 0.010137016820764176, ('31.0', 'bench', 'medium'): 0.014592848390330846, ('15.0', 'heavy', 'squat'): 0.010916787345438342, ('41.0', 'medium', 'squat'): 0.014035869444135011, ('85.0', 'bench', 'medium'): 0.01303330734098251, ('84.0', 'medium', 'ohp'): 0.012142141027069177, ('89.0', 'rest', 'sitting'): 0.01893728417065835, ('29.0', 'bench', 'medium'): 0.014592848390330846, ('57.0', 'medium', 'row'): 0.010582599977720842, ('1.0', 'dead', 'medium'): 0.019382867327615017, ('75.0', 'dead', 'medium'): 0.016040993650440014, ('34.0', 'bench', 'medium'): 0.01236493260554751, ('37.0', 'medium', 'ohp'): 0.014704244179570012, ('56.0', 'medium', 'ohp'): 0.012253536816308343, ('9.0', 'medium', 'squat'): 0.014481452601091679, ('55.0', 'dead', 'medium'): 0.019382867327615017, ('23.0', 'rest', 'standing'): 0.022279157847833353, ('40.0', 'medium', 'row'): 0.010693995766960009, ('68.0', 'dead', 'medium'): 0.01648657680739668, ('82.0', 'rest', 'sitting'): 0.01893728417065835, ('45.0', 'heavy', 'squat'): 0.011473766291634177, ('2.0', 'medium', 'squat'): 0.018714492592180016, ('78.0', 'dead', 'medium'): 0.01826890943522335, ('60.0', 'rest', 'sitting'): 0.01893728417065835, ('51.0', 'rest', 'standing'): 0.022279157847833353, ('53.0', 'medium', 'row'): 0.011807953659351677, ('44.0', 'bench', 'medium'): 0.01236493260554751, ('69.0', 'dead', 'medium'): 0.016040993650440014, ('19.0', 'rest', 'standing'): 0.022279157847833353, ('63.0', 'medium', 'row'): 0.011807953659351677, ('32.0', 'medium', 'row'): 0.01169655787011251, ('79.0', 'heavy', 'squat'): 0.01169655787011251}
# Candidate 4-itemsets: set()
# Frequent 4-itemsets: {}
# Generated rules: []
# Generated rules: [(('60.0',), ('sitting',)), (('sitting',), ('60.0',)), (('29.0',), ('medium',)), (('medium',), ('29.0',)), (('27.0',), ('medium',)), (('medium',), ('27.0',)), (('40.0',), ('medium',)), (('medium',), ('40.0',)), (('45.0',), ('heavy',)), (('heavy',), ('45.0',)), (('15.0',), ('heavy',)), (('heavy',), ('15.0',)), (('31.0',), ('medium',)), (('medium',), ('31.0',)), (('70.0',), ('medium',)), (('medium',), ('70.0',)), (('51.0',), ('standing',)), (('standing',), ('51.0',)), (('41.0',), ('medium',)), (('medium',), ('41.0',)), (('82.0',), ('sitting',)), (('sitting',), ('82.0',)), (('32.0',), ('medium',)), (('medium',), ('32.0',)), (('medium',), ('squat',)), (('squat',), ('medium',)), (('53.0',), ('row',)), (('row',), ('53.0',)), (('dead',), ('medium',)), (('medium',), ('dead',)), (('23.0',), ('standing',)), (('standing',), ('23.0',)), (('heavy',), ('ohp',)), (('ohp',), ('heavy',)), (('14.0',), ('medium',)), (('medium',), ('14.0',)), (('9.0',), ('squat',)), (('squat',), ('9.0',)), (('69.0',), ('dead',)), (('dead',), ('69.0',)), (('rest',), ('sitting',)), (('sitting',), ('rest',)), (('57.0',), ('medium',)), (('medium',), ('57.0',)), (('52.0',), ('ohp',)), (('ohp',), ('52.0',)), (('41.0',), ('squat',)), (('squat',), ('41.0',)), (('85.0',), ('medium',)), (('medium',), ('85.0',)), (('37.0',), ('medium',)), (('medium',), ('37.0',)), (('50.0',), ('bench',)), (('bench',), ('50.0',)), (('79.0',), ('heavy',)), (('heavy',), ('79.0',)), (('75.0',), ('dead',)), (('dead',), ('75.0',)), (('84.0',), ('ohp',)), (('ohp',), ('84.0',)), (('56.0',), ('ohp',)), (('ohp',), ('56.0',)), (('heavy',), ('squat',)), (('squat',), ('heavy',)), (('44.0',), ('medium',)), (('medium',), ('44.0',)), (('9.0',), ('medium',)), (('medium',), ('9.0',)), (('49.0',), ('medium',)), (('medium',), ('49.0',)), (('69.0',), ('medium',)), (('medium',), ('69.0',)), (('47.0',), ('heavy',)), (('heavy',), ('47.0',)), (('2.0',), ('squat',)), (('squat',), ('2.0',)), (('6.0',), ('dead',)), (('dead',), ('6.0',)), (('55.0',), ('dead',)), (('dead',), ('55.0',)), (('77.0',), ('ohp',)), (('ohp',), ('77.0',)), (('3.0',), ('medium',)), (('medium',), ('3.0',)), (('75.0',), ('medium',)), (('medium',), ('75.0',)), (('15.0',), ('squat',)), (('squat',), ('15.0',)), (('19.0',), ('rest',)), (('rest',), ('19.0',)), (('77.0',), ('medium',)), (('medium',), ('77.0',)), (('40.0',), ('row',)), (('row',), ('40.0',)), (('63.0',), ('medium',)), (('medium',), ('63.0',)), (('bench',), ('medium',)), (('medium',), ('bench',)), (('78.0',), ('dead',)), (('dead',), ('78.0',)), (('2.0',), ('medium',)), (('medium',), ('2.0',)), (('89.0',), ('rest',)), (('rest',), ('89.0',)), (('6.0',), ('medium',)), (('medium',), ('6.0',)), (('55.0',), ('medium',)), (('medium',), ('55.0',)), (('34.0',), ('bench',)), (('bench',), ('34.0',)), (('22.0',), ('heavy',)), (('heavy',), ('22.0',)), (('32.0',), ('row',)), (('row',), ('32.0',)), (('11.0',), ('dead',)), (('dead',), ('11.0',)), (('73.0',), ('squat',)), (('squat',), ('73.0',)), (('47.0',), ('ohp',)), (('ohp',), ('47.0',)), (('3.0',), ('row',)), (('row',), ('3.0',)), (('14.0',), ('row',)), (('row',), ('14.0',)), (('84.0',), ('medium',)), (('medium',), ('84.0',)), (('56.0',), ('medium',)), (('medium',), ('56.0',)), (('60.0',), ('rest',)), (('rest',), ('60.0',)), (('29.0',), ('bench',)), (('bench',), ('29.0',)), (('heavy',), ('row',)), (('row',), ('heavy',)), (('dead',), ('heavy',)), (('heavy',), ('dead',)), (('57.0',), ('row',)), (('row',), ('57.0',)), (('50.0',), ('medium',)), (('medium',), ('50.0',)), (('78.0',), ('medium',)), (('medium',), ('78.0',)), (('31.0',), ('bench',)), (('bench',), ('31.0',)), (('19.0',), ('standing',)), (('standing',), ('19.0',)), (('medium',), ('row',)), (('row',), ('medium',)), (('45.0',), ('squat',)), (('squat',), ('45.0',)), (('11.0',), ('medium',)), (('medium',), ('11.0',)), (('53.0',), ('medium',)), (('medium',), ('53.0',)), (('82.0',), ('rest',)), (('rest',), ('82.0',)), (('26.0',), ('medium',)), (('medium',), ('26.0',)), (('68.0',), ('de ...
# Generated rules: [(('22.0',), ('heavy', 'squat')), (('heavy',), ('22.0', 'squat')), (('squat',), ('heavy', '22.0')), (('22.0', 'heavy'), ('squat',)), (('22.0', 'squat'), ('heavy',)), (('heavy', 'squat'), ('22.0',)), (('70.0',), ('medium', 'squat')), (('medium',), ('70.0', 'squat')), (('squat',), ('70.0', 'medium')), (('70.0', 'medium'), ('squat',)), (('70.0', 'squat'), ('medium',)), (('medium', 'squat'), ('70.0',)), (('73.0',), ('heavy', 'squat')), (('heavy',), ('73.0', 'squat')), (('squat',), ('73.0', 'heavy')), (('73.0', 'heavy'), ('squat',)), (('73.0', 'squat'), ('heavy',)), (('heavy', 'squat'), ('73.0',)), (('50.0',), ('medium', 'bench')), (('bench',), ('50.0', 'medium')), (('medium',), ('50.0', 'bench')), (('50.0', 'bench'), ('medium',)), (('50.0', 'medium'), ('bench',)), (('bench', 'medium'), ('50.0',)), (('11.0',), ('dead', 'medium')), (('dead',), ('11.0', 'medium')), (('medium',), ('dead', '11.0')), (('11.0', 'dead'), ('medium',)), (('11.0', 'medium'), ('dead',)), (('dead', 'medium'), ('11.0',)), (('14.0',), ('medium', 'row')), (('medium',), ('14.0', 'row')), (('row',), ('14.0', 'medium')), (('14.0', 'medium'), ('row',)), (('14.0', 'row'), ('medium',)), (('medium', 'row'), ('14.0',)), (('27.0',), ('dead', 'medium')), (('dead',), ('medium', '27.0')), (('medium',), ('dead', '27.0')), (('27.0', 'dead'), ('medium',)), (('27.0', 'medium'), ('dead',)), (('dead', 'medium'), ('27.0',)), (('49.0',), ('medium', 'row')), (('medium',), ('49.0', 'row')), (('row',), ('49.0', 'medium')), (('49.0', 'medium'), ('row',)), (('49.0', 'row'), ('medium',)), (('medium', 'row'), ('49.0',)), (('3.0',), ('medium', 'row')), (('medium',), ('3.0', 'row')), (('row',), ('3.0', 'medium')), (('3.0', 'medium'), ('row',)), (('3.0', 'row'), ('medium',)), (('medium', 'row'), ('3.0',)), (('52.0',), ('ohp', 'heavy')), (('heavy',), ('ohp', '52.0')), (('ohp',), ('heavy', '52.0')), (('52.0', 'heavy'), ('ohp',)), (('52.0', 'ohp'), ('heavy',)), (('heavy', 'ohp'), ('52.0',)), (('77.0',), ('ohp', 'medium')), (('medium',), ('ohp', '77.0')), (('ohp',), ('77.0', 'medium')), (('77.0', 'medium'), ('ohp',)), (('77.0', 'ohp'), ('medium',)), (('medium', 'ohp'), ('77.0',)), (('6.0',), ('dead', 'medium')), (('dead',), ('medium', '6.0')), (('medium',), ('dead', '6.0')), (('6.0', 'dead'), ('medium',)), (('6.0', 'medium'), ('dead',)), (('dead', 'medium'), ('6.0',)), (('26.0',), ('medium', 'squat')), (('medium',), ('26.0', 'squat')), (('squat',), ('26.0', 'medium')), (('26.0', 'medium'), ('squat',)), (('26.0', 'squat'), ('medium',)), (('medium', 'squat'), ('26.0',)), (('47.0',), ('ohp', 'heavy')), (('heavy',), ('47.0', 'ohp')), (('ohp',), ('47.0', 'heavy')), (('47.0', 'heavy'), ('ohp',)), (('47.0', 'ohp'), ('heavy',)), (('heavy', 'ohp'), ('47.0',)), (('31.0',), ('medium', 'bench')), (('bench',), ('31.0', 'medium')), (('medium',), ('31.0', 'bench')), (('31.0', 'bench'), ('medium',)), (('31.0', 'medium'), ('bench',)), (('bench', 'medium'), ('31.0',)), (('15.0',), ('heavy', 'squat')), (('heavy',), ('15.0', 'squat')), (('squat',), ('heavy', '15.0')), (('15.0', 'heavy'), ('squat',)), (('15.0', 'squat'), ('heavy',)), (('heavy', 'squat'), ('15.0',)), (('41.0',), ('medium', 'squat')), (('medium',), ('41.0', 'squat')), (('squat',), ('41.0', 'medium')), (('41.0', 'medium'), ('squat',)), (('41.0', 'squat'), ('medium',)), (('medium', 'squat'), ('41.0',)), (('85.0',), ('medium', 'bench')), (('bench',), ('medium', '85.0')), (('medium',), ('bench', '85.0')), (('85.0', 'bench'), ('medium',)), (('85.0', 'medium'), ('bench',)), (('bench', 'medium'), ('85.0',)), (('84.0',), ('ohp', 'medium')), (('medium',), ('ohp', '84.0')), (('ohp',), ('84.0', 'medium')), (('84.0', 'medium'), ('ohp',)), (('84.0', 'ohp'), ('medium',)), (('medium', 'ohp'), ('84.0',)), (('89.0',), ('rest', 'sitting')), (('rest',), ('89.0', 'sitting')), (('sitting',), ('89.0', 'rest')), (('89.0', 'rest'), ('sitting',)), (('89.0', 'sitting'), ('rest',)), (('rest', 'sitting'), ('89.0',)), (('29.0',), ('medium', 'bench')), (('bench',), ...
# Frequent Itemsets:
# Frequent 1-itemsets: {('56.0',): 0.012253536816308343, ('23.0',): 0.022279157847833353, ('53.0',): 0.011807953659351677, ('57.0',): 0.010693995766960009, ('row',): 0.15695666703798597, ('29.0',): 0.014592848390330846, ('heavy',): 0.38364709813969033, ('50.0',): 0.01303330734098251, ('31.0',): 0.014592848390330846, ('37.0',): 0.014704244179570012, ('22.0',): 0.010916787345438342, ('bench',): 0.18458282276929933, ('rest',): 0.1236493260554751, ('26.0',): 0.013924473654895846, ('82.0',): 0.01893728417065835, ('27.0',): 0.015038431547287512, ('34.0',): 0.01236493260554751, ('1.0',): 0.019494263116854184, ('73.0',): 0.011473766291634177, ('79.0',): 0.01169655787011251, ('44.0',): 0.01236493260554751, ('6.0',): 0.016709368385875015, ('68.0',): 0.01648657680739668, ('55.0',): 0.019382867327615017, ('77.0',): 0.010805391556199176, ('45.0',): 0.011473766291634177, ('78.0',): 0.01826890943522335, ('32.0',): 0.01169655787011251, ('19.0',): 0.022279157847833353, ('standing',): 0.06683747354350006, ('52.0',): 0.010471204188481676, ('dead',): 0.17043555753592515, ('70.0',): 0.014481452601091679, ('40.0',): 0.010693995766960009, ('51.0',): 0.022279157847833353, ('75.0',): 0.016040993650440014, ('89.0',): 0.01893728417065835, ('3.0',): 0.011585162080873342, ('47.0',): 0.010137016820764176, ('ohp',): 0
0', 'medium', 'ohp'): 0.014704244179570012, ('56.0', 'medium', 'ohp'): 0.012253536816308343, ('9.0', 'medium', 'squat'): 0.014481452601091679, ('55.0', 'dead', 'medium'): 0.019382867327615017, ('23.0', 'rest', 'standing'): 0.022279157847833353, ('40.0', 'medium', 'row'): 0.010693995766960009, ('68.0', 'dead', 'medium'): 0.01648657680739668, ('82.0', 'rest', 'sitting'): 0.01893728417065835, ('45.0', 'heavy', 'squat'): 0.011473766291634177, ('2.0', 'medium', 'squat'): 0.018714492592180016, ('78.0', 'dead', 'medium'): 0.01826890943522335, ('60.0', 'rest', 'sitting'): 0.01893728417065835, ('51.0', 'rest', 'standing'): 0.022279157847833353, ('53.0', 'medium', 'row'): 0.011807953659351677, ('44.0', 'bench', 'medium'): 0.01236493260554751, ('69.0', 'dead', 'medium'): 0.016040993650440014, ('19.0', 'rest', 'standing'): 0.022279157847833353, ('63.0', 'medium', 'row'): 0.011807953659351677, ('32.0', 'medium', 'row'): 0.01169655787011251, ('79.0', 'heavy', 'squat'): 0.01169655787011251}
#
# Association Rules:
# Rule: ('60.0',) => ('sitting',), Confidence: 1.00
# Rule: ('sitting',) => ('60.0',), Confidence: 0.33
# Rule: ('29.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('29.0',), Confidence: 0.03
# Rule: ('27.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('27.0',), Confidence: 0.03
# Rule: ('40.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('40.0',), Confidence: 0.02
# Rule: ('45.0',) => ('heavy',), Confidence: 1.00
# Rule: ('heavy',) => ('45.0',), Confidence: 0.03
# Rule: ('15.0',) => ('heavy',), Confidence: 1.00
# Rule: ('heavy',) => ('15.0',), Confidence: 0.03
# Rule: ('31.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('31.0',), Confidence: 0.03
# Rule: ('70.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('70.0',), Confidence: 0.03
# Rule: ('51.0',) => ('standing',), Confidence: 1.00
# Rule: ('standing',) => ('51.0',), Confidence: 0.33
# Rule: ('41.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('41.0',), Confidence: 0.03
# Rule: ('82.0',) => ('sitting',), Confidence: 1.00
# Rule: ('sitting',) => ('82.0',), Confidence: 0.33
# Rule: ('32.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('32.0',), Confidence: 0.02
# Rule: ('medium',) => ('squat',), Confidence: 0.17
# Rule: ('squat',) => ('medium',), Confidence: 0.47
# Rule: ('53.0',) => ('row',), Confidence: 1.00
# Rule: ('row',) => ('53.0',), Confidence: 0.08
# Rule: ('dead',) => ('medium',), Confidence: 0.89
# Rule: ('medium',) => ('dead',), Confidence: 0.31
# Rule: ('23.0',) => ('standing',), Confidence: 1.00
# Rule: ('standing',) => ('23.0',), Confidence: 0.33
# Rule: ('heavy',) => ('ohp',), Confidence: 0.31
# Rule: ('ohp',) => ('heavy',), Confidence: 0.64
# Rule: ('14.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('14.0',), Confidence: 0.02
# Rule: ('9.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('9.0',), Confidence: 0.08
# Rule: ('69.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('69.0',), Confidence: 0.09
# Rule: ('rest',) => ('sitting',), Confidence: 0.46
# Rule: ('sitting',) => ('rest',), Confidence: 1.00
# Rule: ('57.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('57.0',), Confidence: 0.02
# Rule: ('52.0',) => ('ohp',), Confidence: 1.00
# Rule: ('ohp',) => ('52.0',), Confidence: 0.06
# Rule: ('41.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('41.0',), Confidence: 0.08
# Rule: ('85.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('85.0',), Confidence: 0.03
# Rule: ('37.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('37.0',), Confidence: 0.03
# Rule: ('50.0',) => ('bench',), Confidence: 1.00
# Rule: ('bench',) => ('50.0',), Confidence: 0.07
# Rule: ('79.0',) => ('heavy',), Confidence: 1.00
# Rule: ('heavy',) => ('79.0',), Confidence: 0.03
# Rule: ('75.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('75.0',), Confidence: 0.09
# Rule: ('84.0',) => ('ohp',), Confidence: 1.00
# Rule: ('ohp',) => ('84.0',), Confidence: 0.07
# Rule: ('56.0',) => ('ohp',), Confidence: 1.00
# Rule: ('ohp',) => ('56.0',), Confidence: 0.07
# Rule: ('heavy',) => ('squat',), Confidence: 0.24
# Rule: ('squat',) => ('heavy',), Confidence: 0.53
# Rule: ('44.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('44.0',), Confidence: 0.03
# Rule: ('9.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('9.0',), Confidence: 0.03
# Rule: ('49.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('49.0',), Confidence: 0.02
# Rule: ('69.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('69.0',), Confidence: 0.03
# Rule: ('47.0',) => ('heavy',), Confidence: 1.00
# Rule: ('heavy',) => ('47.0',), Confidence: 0.03
# Rule: ('2.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('2.0',), Confidence: 0.10
# Rule: ('6.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('6.0',), Confidence: 0.10
# Rule: ('55.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('55.0',), Confidence: 0.11
# Rule: ('77.0',) => ('ohp',), Confidence: 1.00
# Rule: ('ohp',) => ('77.0',), Confidence: 0.06
# Rule: ('3.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('3.0',), Confidence: 0.02
# Rule: ('75.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('75.0',), Confidence: 0.03
# Rule: ('15.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('15.0',), Confidence: 0.06
# Rule: ('19.0',) => ('rest',), Confidence: 1.00
# Rule: ('rest',) => ('19.0',), Confidence: 0.18
# Rule: ('77.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('77.0',), Confidence: 0.02
# Rule: ('40.0',) => ('row',), Confidence: 1.00
# Rule: ('row',) => ('40.0',), Confidence: 0.07
# Rule: ('63.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('63.0',), Confidence: 0.02
# Rule: ('bench',) => ('medium',), Confidence: 0.43
# Rule: ('medium',) => ('bench',), Confidence: 0.16
# Rule: ('78.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('78.0',), Confidence: 0.11
# Rule: ('2.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('2.0',), Confidence: 0.04
# Rule: ('89.0',) => ('rest',), Confidence: 1.00
# Rule: ('rest',) => ('89.0',), Confidence: 0.15
# Rule: ('6.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('6.0',), Confidence: 0.03
# Rule: ('55.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('55.0',), Confidence: 0.04
# Rule: ('34.0',) => ('bench',), Confidence: 1.00
# Rule: ('bench',) => ('34.0',), Confidence: 0.07
# Rule: ('22.0',) => ('heavy',), Confidence: 1.00
# Rule: ('heavy',) => ('22.0',), Confidence: 0.03
# Rule: ('32.0',) => ('row',), Confidence: 1.00
# Rule: ('row',) => ('32.0',), Confidence: 0.07
# Rule: ('11.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('11.0',), Confidence: 0.09
# Rule: ('73.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('73.0',), Confidence: 0.06
# Rule: ('47.0',) => ('ohp',), Confidence: 1.00
# Rule: ('ohp',) => ('47.0',), Confidence: 0.05
# Rule: ('3.0',) => ('row',), Confidence: 1.00
# Rule: ('row',) => ('3.0',), Confidence: 0.07
# Rule: ('14.0',) => ('row',), Confidence: 1.00
# Rule: ('row',) => ('14.0',), Confidence: 0.08
# Rule: ('84.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('84.0',), Confidence: 0.02
# Rule: ('56.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('56.0',), Confidence: 0.02
# Rule: ('60.0',) => ('rest',), Confidence: 1.00
# Rule: ('rest',) => ('60.0',), Confidence: 0.15
# Rule: ('29.0',) => ('bench',), Confidence: 1.00
# Rule: ('bench',) => ('29.0',), Confidence: 0.08
# Rule: ('heavy',) => ('row',), Confidence: 0.13
# Rule: ('row',) => ('heavy',), Confidence: 0.31
# Rule: ('dead',) => ('heavy',), Confidence: 0.11
# Rule: ('heavy',) => ('dead',), Confidence: 0.05
# Rule: ('57.0',) => ('row',), Confidence: 0.99
# Rule: ('row',) => ('57.0',), Confidence: 0.07
# Rule: ('50.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('50.0',), Confidence: 0.03
# Rule: ('78.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('78.0',), Confidence: 0.04
# Rule: ('31.0',) => ('bench',), Confidence: 1.00
# Rule: ('bench',) => ('31.0',), Confidence: 0.08
# Rule: ('19.0',) => ('standing',), Confidence: 1.00
# Rule: ('standing',) => ('19.0',), Confidence: 0.33
# Rule: ('medium',) => ('row',), Confidence: 0.22
# Rule: ('row',) => ('medium',), Confidence: 0.69
# Rule: ('45.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('45.0',), Confidence: 0.06
# Rule: ('11.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('11.0',), Confidence: 0.03
# Rule: ('53.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('53.0',), Confidence: 0.02
# Rule: ('82.0',) => ('rest',), Confidence: 1.00
# Rule: ('rest',) => ('82.0',), Confidence: 0.15
# Rule: ('26.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('26.0',), Confidence: 0.03
# Rule: ('68.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('68.0',), Confidence: 0.10
# Rule: ('49.0',) => ('row',), Confidence: 1.00
# Rule: ('row',) => ('49.0',), Confidence: 0.07
# Rule: ('1.0',) => ('dead',), Confidence: 0.99
# Rule: ('dead',) => ('1.0',), Confidence: 0.11
# Rule: ('rest',) => ('standing',), Confidence: 0.54
# Rule: ('standing',) => ('rest',), Confidence: 1.00
# Rule: ('85.0',) => ('bench',), Confidence: 1.00
# Rule: ('bench',) => ('85.0',), Confidence: 0.07
# Rule: ('26.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('26.0',), Confidence: 0.08
# Rule: ('68.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('68.0',), Confidence: 0.03
# Rule: ('51.0',) => ('rest',), Confidence: 1.00
# Rule: ('rest',) => ('51.0',), Confidence: 0.18
# Rule: ('27.0',) => ('dead',), Confidence: 1.00
# Rule: ('dead',) => ('27.0',), Confidence: 0.09
# Rule: ('89.0',) => ('sitting',), Confidence: 1.00
# Rule: ('sitting',) => ('89.0',), Confidence: 0.33
# Rule: ('73.0',) => ('heavy',), Confidence: 1.00
# Rule: ('heavy',) => ('73.0',), Confidence: 0.03
# Rule: ('1.0',) => ('medium',), Confidence: 0.99
# Rule: ('medium',) => ('1.0',), Confidence: 0.04
# Rule: ('63.0',) => ('row',), Confidence: 1.00
# Rule: ('row',) => ('63.0',), Confidence: 0.08
# Rule: ('79.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('79.0',), Confidence: 0.07
# Rule: ('22.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('22.0',), Confidence: 0.06
# Rule: ('23.0',) => ('rest',), Confidence: 1.00
# Rule: ('rest',) => ('23.0',), Confidence: 0.18
# Rule: ('37.0',) => ('ohp',), Confidence: 1.00
# Rule: ('ohp',) => ('37.0',), Confidence: 0.08
# Rule: ('44.0',) => ('bench',), Confidence: 1.00
# Rule: ('bench',) => ('44.0',), Confidence: 0.07
# Rule: ('34.0',) => ('medium',), Confidence: 1.00
# Rule: ('medium',) => ('34.0',), Confidence: 0.03
# Rule: ('70.0',) => ('squat',), Confidence: 1.00
# Rule: ('squat',) => ('70.0',), Confidence: 0.08
# Rule: ('medium',) => ('ohp',), Confidence: 0.14
# Rule: ('ohp',) => ('medium',), Confidence: 0.36
# Rule: ('bench',) => ('heavy',), Confidence: 0.57
# Rule: ('heavy',) => ('bench',), Confidence: 0.27
# Rule: ('52.0',) => ('heavy',), Confidence: 1.00
# Rule: ('heavy',) => ('52.0',), Confidence: 0.03
# Rule: ('22.0',) => ('heavy', 'squat'), Confidence: 1.00
# Rule: ('heavy',) => ('22.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('heavy', '22.0'), Confidence: 0.06
# Rule: ('22.0', 'heavy') => ('squat',), Confidence: 1.00
# Rule: ('22.0', 'squat') => ('heavy',), Confidence: 1.00
# Rule: ('heavy', 'squat') => ('22.0',), Confidence: 0.12
# Rule: ('70.0',) => ('medium', 'squat'), Confidence: 1.00
# Rule: ('medium',) => ('70.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('70.0', 'medium'), Confidence: 0.08
# Rule: ('70.0', 'medium') => ('squat',), Confidence: 1.00
# Rule: ('70.0', 'squat') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'squat') => ('70.0',), Confidence: 0.17
# Rule: ('73.0',) => ('heavy', 'squat'), Confidence: 1.00
# Rule: ('heavy',) => ('73.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('73.0', 'heavy'), Confidence: 0.06
# Rule: ('73.0', 'heavy') => ('squat',), Confidence: 1.00
# Rule: ('73.0', 'squat') => ('heavy',), Confidence: 1.00
# Rule: ('heavy', 'squat') => ('73.0',), Confidence: 0.12
# Rule: ('50.0',) => ('medium', 'bench'), Confidence: 1.00
# Rule: ('bench',) => ('50.0', 'medium'), Confidence: 0.07
# Rule: ('medium',) => ('50.0', 'bench'), Confidence: 0.03
# Rule: ('50.0', 'bench') => ('medium',), Confidence: 1.00
# Rule: ('50.0', 'medium') => ('bench',), Confidence: 1.00
# Rule: ('bench', 'medium') => ('50.0',), Confidence: 0.16
# Rule: ('11.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('11.0', 'medium'), Confidence: 0.09
# Rule: ('medium',) => ('dead', '11.0'), Confidence: 0.03
# Rule: ('11.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('11.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('11.0',), Confidence: 0.10
# Rule: ('14.0',) => ('medium', 'row'), Confidence: 1.00
# Rule: ('medium',) => ('14.0', 'row'), Confidence: 0.02
# Rule: ('row',) => ('14.0', 'medium'), Confidence: 0.08
# Rule: ('14.0', 'medium') => ('row',), Confidence: 1.00
# Rule: ('14.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('14.0',), Confidence: 0.11
# Rule: ('27.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('medium', '27.0'), Confidence: 0.09
# Rule: ('medium',) => ('dead', '27.0'), Confidence: 0.03
# Rule: ('27.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('27.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('27.0',), Confidence: 0.10
# Rule: ('49.0',) => ('medium', 'row'), Confidence: 1.00
# Rule: ('medium',) => ('49.0', 'row'), Confidence: 0.02
# Rule: ('row',) => ('49.0', 'medium'), Confidence: 0.07
# Rule: ('49.0', 'medium') => ('row',), Confidence: 1.00
# Rule: ('49.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('49.0',), Confidence: 0.10
# Rule: ('3.0',) => ('medium', 'row'), Confidence: 1.00
# Rule: ('medium',) => ('3.0', 'row'), Confidence: 0.02
# Rule: ('row',) => ('3.0', 'medium'), Confidence: 0.07
# Rule: ('3.0', 'medium') => ('row',), Confidence: 1.00
# Rule: ('3.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('3.0',), Confidence: 0.11
# Rule: ('52.0',) => ('ohp', 'heavy'), Confidence: 1.00
# Rule: ('heavy',) => ('ohp', '52.0'), Confidence: 0.03
# Rule: ('ohp',) => ('heavy', '52.0'), Confidence: 0.06
# Rule: ('52.0', 'heavy') => ('ohp',), Confidence: 1.00
# Rule: ('52.0', 'ohp') => ('heavy',), Confidence: 1.00
# Rule: ('heavy', 'ohp') => ('52.0',), Confidence: 0.09
# Rule: ('77.0',) => ('ohp', 'medium'), Confidence: 1.00
# Rule: ('medium',) => ('ohp', '77.0'), Confidence: 0.02
# Rule: ('ohp',) => ('77.0', 'medium'), Confidence: 0.06
# Rule: ('77.0', 'medium') => ('ohp',), Confidence: 1.00
# Rule: ('77.0', 'ohp') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'ohp') => ('77.0',), Confidence: 0.16
# Rule: ('6.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('medium', '6.0'), Confidence: 0.10
# Rule: ('medium',) => ('dead', '6.0'), Confidence: 0.03
# Rule: ('6.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('6.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('6.0',), Confidence: 0.11
# Rule: ('26.0',) => ('medium', 'squat'), Confidence: 1.00
# Rule: ('medium',) => ('26.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('26.0', 'medium'), Confidence: 0.08
# Rule: ('26.0', 'medium') => ('squat',), Confidence: 1.00
# Rule: ('26.0', 'squat') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'squat') => ('26.0',), Confidence: 0.17
# Rule: ('47.0',) => ('ohp', 'heavy'), Confidence: 1.00
# Rule: ('heavy',) => ('47.0', 'ohp'), Confidence: 0.03
# Rule: ('ohp',) => ('47.0', 'heavy'), Confidence: 0.05
# Rule: ('47.0', 'heavy') => ('ohp',), Confidence: 1.00
# Rule: ('47.0', 'ohp') => ('heavy',), Confidence: 1.00
# Rule: ('heavy', 'ohp') => ('47.0',), Confidence: 0.09
# Rule: ('31.0',) => ('medium', 'bench'), Confidence: 1.00
# Rule: ('bench',) => ('31.0', 'medium'), Confidence: 0.08
# Rule: ('medium',) => ('31.0', 'bench'), Confidence: 0.03
# Rule: ('31.0', 'bench') => ('medium',), Confidence: 1.00
# Rule: ('31.0', 'medium') => ('bench',), Confidence: 1.00
# Rule: ('bench', 'medium') => ('31.0',), Confidence: 0.18
# Rule: ('15.0',) => ('heavy', 'squat'), Confidence: 1.00
# Rule: ('heavy',) => ('15.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('heavy', '15.0'), Confidence: 0.06
# Rule: ('15.0', 'heavy') => ('squat',), Confidence: 1.00
# Rule: ('15.0', 'squat') => ('heavy',), Confidence: 1.00
# Rule: ('heavy', 'squat') => ('15.0',), Confidence: 0.12
# Rule: ('41.0',) => ('medium', 'squat'), Confidence: 1.00
# Rule: ('medium',) => ('41.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('41.0', 'medium'), Confidence: 0.08
# Rule: ('41.0', 'medium') => ('squat',), Confidence: 1.00
# Rule: ('41.0', 'squat') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'squat') => ('41.0',), Confidence: 0.17
# Rule: ('85.0',) => ('medium', 'bench'), Confidence: 1.00
# Rule: ('bench',) => ('medium', '85.0'), Confidence: 0.07
# Rule: ('medium',) => ('bench', '85.0'), Confidence: 0.03
# Rule: ('85.0', 'bench') => ('medium',), Confidence: 1.00
# Rule: ('85.0', 'medium') => ('bench',), Confidence: 1.00
# Rule: ('bench', 'medium') => ('85.0',), Confidence: 0.16
# Rule: ('84.0',) => ('ohp', 'medium'), Confidence: 1.00
# Rule: ('medium',) => ('ohp', '84.0'), Confidence: 0.02
# Rule: ('ohp',) => ('84.0', 'medium'), Confidence: 0.07
# Rule: ('84.0', 'medium') => ('ohp',), Confidence: 1.00
# Rule: ('84.0', 'ohp') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'ohp') => ('84.0',), Confidence: 0.18
# Rule: ('89.0',) => ('rest', 'sitting'), Confidence: 1.00
# Rule: ('rest',) => ('89.0', 'sitting'), Confidence: 0.15
# Rule: ('sitting',) => ('89.0', 'rest'), Confidence: 0.33
# Rule: ('89.0', 'rest') => ('sitting',), Confidence: 1.00
# Rule: ('89.0', 'sitting') => ('rest',), Confidence: 1.00
# Rule: ('rest', 'sitting') => ('89.0',), Confidence: 0.33
# Rule: ('29.0',) => ('medium', 'bench'), Confidence: 1.00
# Rule: ('bench',) => ('29.0', 'medium'), Confidence: 0.08
# Rule: ('medium',) => ('29.0', 'bench'), Confidence: 0.03
# Rule: ('29.0', 'bench') => ('medium',), Confidence: 1.00
# Rule: ('29.0', 'medium') => ('bench',), Confidence: 1.00
# Rule: ('bench', 'medium') => ('29.0',), Confidence: 0.18
# Rule: ('57.0',) => ('medium', 'row'), Confidence: 0.99
# Rule: ('medium',) => ('57.0', 'row'), Confidence: 0.02
# Rule: ('row',) => ('57.0', 'medium'), Confidence: 0.07
# Rule: ('57.0', 'medium') => ('row',), Confidence: 0.99
# Rule: ('57.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('57.0',), Confidence: 0.10
# Rule: ('1.0',) => ('dead', 'medium'), Confidence: 0.99
# Rule: ('dead',) => ('1.0', 'medium'), Confidence: 0.11
# Rule: ('medium',) => ('dead', '1.0'), Confidence: 0.04
# Rule: ('1.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('1.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('1.0',), Confidence: 0.13
# Rule: ('75.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('75.0', 'medium'), Confidence: 0.09
# Rule: ('medium',) => ('75.0', 'dead'), Confidence: 0.03
# Rule: ('75.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('75.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('75.0',), Confidence: 0.11
# Rule: ('34.0',) => ('medium', 'bench'), Confidence: 1.00
# Rule: ('bench',) => ('medium', '34.0'), Confidence: 0.07
# Rule: ('medium',) => ('34.0', 'bench'), Confidence: 0.03
# Rule: ('34.0', 'bench') => ('medium',), Confidence: 1.00
# Rule: ('34.0', 'medium') => ('bench',), Confidence: 1.00
# Rule: ('bench', 'medium') => ('34.0',), Confidence: 0.15
# Rule: ('37.0',) => ('ohp', 'medium'), Confidence: 1.00
# Rule: ('medium',) => ('ohp', '37.0'), Confidence: 0.03
# Rule: ('ohp',) => ('medium', '37.0'), Confidence: 0.08
# Rule: ('37.0', 'medium') => ('ohp',), Confidence: 1.00
# Rule: ('37.0', 'ohp') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'ohp') => ('37.0',), Confidence: 0.22
# Rule: ('56.0',) => ('ohp', 'medium'), Confidence: 1.00
# Rule: ('medium',) => ('ohp', '56.0'), Confidence: 0.02
# Rule: ('ohp',) => ('medium', '56.0'), Confidence: 0.07
# Rule: ('56.0', 'medium') => ('ohp',), Confidence: 1.00
# Rule: ('56.0', 'ohp') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'ohp') => ('56.0',), Confidence: 0.18
# Rule: ('9.0',) => ('medium', 'squat'), Confidence: 1.00
# Rule: ('medium',) => ('squat', '9.0'), Confidence: 0.03
# Rule: ('squat',) => ('medium', '9.0'), Confidence: 0.08
# Rule: ('9.0', 'medium') => ('squat',), Confidence: 1.00
# Rule: ('9.0', 'squat') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'squat') => ('9.0',), Confidence: 0.17
# Rule: ('55.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('55.0', 'medium'), Confidence: 0.11
# Rule: ('medium',) => ('55.0', 'dead'), Confidence: 0.04
# Rule: ('55.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('55.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('55.0',), Confidence: 0.13
# Rule: ('23.0',) => ('standing', 'rest'), Confidence: 1.00
# Rule: ('rest',) => ('standing', '23.0'), Confidence: 0.18
# Rule: ('standing',) => ('rest', '23.0'), Confidence: 0.33
# Rule: ('23.0', 'rest') => ('standing',), Confidence: 1.00
# Rule: ('23.0', 'standing') => ('rest',), Confidence: 1.00
# Rule: ('rest', 'standing') => ('23.0',), Confidence: 0.33
# Rule: ('40.0',) => ('medium', 'row'), Confidence: 1.00
# Rule: ('medium',) => ('40.0', 'row'), Confidence: 0.02
# Rule: ('row',) => ('40.0', 'medium'), Confidence: 0.07
# Rule: ('40.0', 'medium') => ('row',), Confidence: 1.00
# Rule: ('40.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('40.0',), Confidence: 0.10
# Rule: ('68.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('68.0', 'medium'), Confidence: 0.10
# Rule: ('medium',) => ('68.0', 'dead'), Confidence: 0.03
# Rule: ('68.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('68.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('68.0',), Confidence: 0.11
# Rule: ('82.0',) => ('rest', 'sitting'), Confidence: 1.00
# Rule: ('rest',) => ('sitting', '82.0'), Confidence: 0.15
# Rule: ('sitting',) => ('rest', '82.0'), Confidence: 0.33
# Rule: ('82.0', 'rest') => ('sitting',), Confidence: 1.00
# Rule: ('82.0', 'sitting') => ('rest',), Confidence: 1.00
# Rule: ('rest', 'sitting') => ('82.0',), Confidence: 0.33
# Rule: ('45.0',) => ('heavy', 'squat'), Confidence: 1.00
# Rule: ('heavy',) => ('45.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('heavy', '45.0'), Confidence: 0.06
# Rule: ('45.0', 'heavy') => ('squat',), Confidence: 1.00
# Rule: ('45.0', 'squat') => ('heavy',), Confidence: 1.00
# Rule: ('heavy', 'squat') => ('45.0',), Confidence: 0.12
# Rule: ('2.0',) => ('medium', 'squat'), Confidence: 1.00
# Rule: ('medium',) => ('2.0', 'squat'), Confidence: 0.04
# Rule: ('squat',) => ('2.0', 'medium'), Confidence: 0.10
# Rule: ('2.0', 'medium') => ('squat',), Confidence: 1.00
# Rule: ('2.0', 'squat') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'squat') => ('2.0',), Confidence: 0.22
# Rule: ('78.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('78.0', 'medium'), Confidence: 0.11
# Rule: ('medium',) => ('dead', '78.0'), Confidence: 0.04
# Rule: ('78.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('78.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('78.0',), Confidence: 0.12
# Rule: ('60.0',) => ('rest', 'sitting'), Confidence: 1.00
# Rule: ('rest',) => ('sitting', '60.0'), Confidence: 0.15
# Rule: ('sitting',) => ('rest', '60.0'), Confidence: 0.33
# Rule: ('60.0', 'rest') => ('sitting',), Confidence: 1.00
# Rule: ('60.0', 'sitting') => ('rest',), Confidence: 1.00
# Rule: ('rest', 'sitting') => ('60.0',), Confidence: 0.33
# Rule: ('51.0',) => ('standing', 'rest'), Confidence: 1.00
# Rule: ('rest',) => ('standing', '51.0'), Confidence: 0.18
# Rule: ('standing',) => ('51.0', 'rest'), Confidence: 0.33
# Rule: ('51.0', 'rest') => ('standing',), Confidence: 1.00
# Rule: ('51.0', 'standing') => ('rest',), Confidence: 1.00
# Rule: ('rest', 'standing') => ('51.0',), Confidence: 0.33
# Rule: ('53.0',) => ('medium', 'row'), Confidence: 1.00
# Rule: ('medium',) => ('53.0', 'row'), Confidence: 0.02
# Rule: ('row',) => ('53.0', 'medium'), Confidence: 0.08
# Rule: ('53.0', 'medium') => ('row',), Confidence: 1.00
# Rule: ('53.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('53.0',), Confidence: 0.11
# Rule: ('44.0',) => ('medium', 'bench'), Confidence: 1.00
# Rule: ('bench',) => ('medium', '44.0'), Confidence: 0.07
# Rule: ('medium',) => ('bench', '44.0'), Confidence: 0.03
# Rule: ('44.0', 'bench') => ('medium',), Confidence: 1.00
# Rule: ('44.0', 'medium') => ('bench',), Confidence: 1.00
# Rule: ('bench', 'medium') => ('44.0',), Confidence: 0.15
# Rule: ('69.0',) => ('dead', 'medium'), Confidence: 1.00
# Rule: ('dead',) => ('69.0', 'medium'), Confidence: 0.09
# Rule: ('medium',) => ('69.0', 'dead'), Confidence: 0.03
# Rule: ('69.0', 'dead') => ('medium',), Confidence: 1.00
# Rule: ('69.0', 'medium') => ('dead',), Confidence: 1.00
# Rule: ('dead', 'medium') => ('69.0',), Confidence: 0.11
# Rule: ('19.0',) => ('standing', 'rest'), Confidence: 1.00
# Rule: ('rest',) => ('standing', '19.0'), Confidence: 0.18
# Rule: ('standing',) => ('19.0', 'rest'), Confidence: 0.33
# Rule: ('19.0', 'rest') => ('standing',), Confidence: 1.00
# Rule: ('19.0', 'standing') => ('rest',), Confidence: 1.00
# Rule: ('rest', 'standing') => ('19.0',), Confidence: 0.33
# Rule: ('63.0',) => ('medium', 'row'), Confidence: 1.00
# Rule: ('medium',) => ('63.0', 'row'), Confidence: 0.02
# Rule: ('row',) => ('63.0', 'medium'), Confidence: 0.08
# Rule: ('63.0', 'medium') => ('row',), Confidence: 1.00
# Rule: ('63.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('63.0',), Confidence: 0.11
# Rule: ('32.0',) => ('medium', 'row'), Confidence: 1.00
# Rule: ('medium',) => ('row', '32.0'), Confidence: 0.02
# Rule: ('row',) => ('medium', '32.0'), Confidence: 0.07
# Rule: ('32.0', 'medium') => ('row',), Confidence: 1.00
# Rule: ('32.0', 'row') => ('medium',), Confidence: 1.00
# Rule: ('medium', 'row') => ('32.0',), Confidence: 0.11
# Rule: ('79.0',) => ('heavy', 'squat'), Confidence: 1.00
# Rule: ('heavy',) => ('79.0', 'squat'), Confidence: 0.03
# Rule: ('squat',) => ('heavy', '79.0'), Confidence: 0.07
# Rule: ('79.0', 'heavy') => ('squat',), Confidence: 1.00
# Rule: ('79.0', 'squat') => ('heavy',), Confidence: 1.00
# Rule: ('heavy', 'squat') => ('79.0',), Confidence: 0.12
